# %% [markdown]
# # Data Transformation

# %% [markdown]
# Data in different scales.
#
# Values in a dataset might have a variety of different magnitudes, ranges, or scales.
# Algorithms that use distance as a parameter may not weigh all these in the same way.
# There are various data transformation techniques that are used to transform the features of our data so that they use the same scale, magnitude, or range.
# This ensures that each feature has an appropriate effect on a model's predictions.
# Some features in our data might have high-magnitude values (for example, annual salary), while others might have relatively low values (for example, the number of years worked at a company). Just because some data has smaller values does not mean it is less significant.
#
# Reference: Data Science with Python
# By Rohan Chopra, Aaron England, Mohamed Noordeen Alaudeen
# July 2019
#
# https://subscription.packtpub.com/book/data/9781838552862/1/ch01lvl1sec08/data-in-different-scales

# %% [markdown]
# # Implementing Scaling Using the Standard Scaler Method

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Wholesale customers data.csv')

# %%
df.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
dtypes = df.dtypes
dtypes
# Out:
# Channel             int64
# Region              int64
# Fresh               int64
# Milk                int64
# Grocery             int64
# Frozen              int64
# Detergents_Paper    int64
# Delicassen          int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel           440 non-null    int64
#  1   Region            440 non-null    int64
#  2   Fresh             440 non-null    int64
#  3   Milk              440 non-null    int64
#  4   Grocery           440 non-null    int64
#  5   Frozen            440 non-null    int64
#  6   Detergents_Paper  440 non-null    int64
#  7   Delicassen        440 non-null    int64
# dtypes: int64(8)
# memory usage: 27.6 KB

# %%
sns.barplot(data=df, x="Channel", y="Milk", estimator=sum, ci=None, palette=['red', 'blue'])
plt.xlabel("Canal")
plt.ylabel("Cantidad de Leche")
plt.title("Consumo de Leche por Canal")
plt.show()
# Out:
# <ipython-input-7-d3cd58d87ac0>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="Channel", y="Milk", estimator=sum, ci=None, palette=['red', 'blue'])
# <ipython-input-7-d3cd58d87ac0>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="Channel", y="Milk", estimator=sum, ci=None, palette=['red', 'blue'])

# %% [markdown]
# Perform standard scaling and print the first five rows of the new dataset. To do so, use the StandardScaler() class from sklearn.preprocessing and implement the fit_transorm() method.
# Using the StandardScaler method, we will scale the data into a uniform unit over all the columns.
# The values of all the features will be converted into a uniform range of the same scale. Because of this, it becomes easier for the model to make predictions.

# %%
from sklearn import preprocessing
std_scale = preprocessing.StandardScaler().fit_transform(df)
scaled_frame = pd.DataFrame(std_scale, columns=df.columns)

scaled_frame.head()
# Out:
#     Channel    Region     Fresh      Milk   Grocery    Frozen  \
# 0  1.448652  0.590668  0.052933  0.523568 -0.041115 -0.589367
# 1  1.448652  0.590668 -0.391302  0.544458  0.170318 -0.270136
# 2  1.448652  0.590668 -0.447029  0.408538 -0.028157 -0.137536
# 3 -0.690297  0.590668  0.100111 -0.624020 -0.392977  0.687144
# 4  1.448652  0.590668  0.840239 -0.052396 -0.079356  0.173859
#
#    Detergents_Paper  Delicassen
# 0         -0.043569   -0.066339
# 1          0.086407    0.089151
# 2          0.133232    2.243293
# 3         -0.498588    0.093411
# 4         -0.231918    1.299347

# %%
sns.barplot(data=scaled_frame, x="Channel", y="Milk", estimator=sum, ci=None, palette=['red', 'blue'])
plt.xlabel("Canal")
plt.ylabel("Cantidad de Leche")
plt.title("Consumo de Leche por Canal")
plt.show()
# Out:
# <ipython-input-9-d26bba7067c3>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=scaled_frame, x="Channel", y="Milk", estimator=sum, ci=None, palette=['red', 'blue'])
# <ipython-input-9-d26bba7067c3>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=scaled_frame, x="Channel", y="Milk", estimator=sum, ci=None, palette=['red', 'blue'])

# %% [markdown]
# # Implementing Scaling Using the MinMax Scaler Method

# %% [markdown]
# Perform MinMax scaling and print the initial five values of the new dataset. To do so, use the MinMaxScaler() class from sklearn.preprocessing and implement the fit_transorm() method. Add the following code to implement this:
# Using the MinMaxScaler method, we will scale the data into a uniform unit over all the columns

# %%
from sklearn import preprocessing
minmax_scale = preprocessing.MinMaxScaler().fit_transform(df)
scaled_frame2 = pd.DataFrame(minmax_scale,columns=df.columns)
scaled_frame2.head()
# Out:
#    Channel  Region     Fresh      Milk   Grocery    Frozen  Detergents_Paper  \
# 0      1.0     1.0  0.112940  0.130727  0.081464  0.003106          0.065427
# 1      1.0     1.0  0.062899  0.132824  0.103097  0.028548          0.080590
# 2      1.0     1.0  0.056622  0.119181  0.082790  0.039116          0.086052
# 3      0.0     1.0  0.118254  0.015536  0.045464  0.104842          0.012346
# 4      1.0     1.0  0.201626  0.072914  0.077552  0.063934          0.043455
#
#    Delicassen
# 0    0.027847
# 1    0.036984
# 2    0.163559
# 3    0.037234
# 4    0.108093

# %%
sns.barplot(data=scaled_frame2, x="Channel", y="Milk", estimator=sum, ci=None, palette=['red', 'blue'])
plt.xlabel("Canal")
plt.ylabel("Cantidad de Leche")
plt.title("Consumo de Leche por Canal")
plt.show()
# Out:
# <ipython-input-11-57e7edc93347>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=scaled_frame2, x="Channel", y="Milk", estimator=sum, ci=None, palette=['red', 'blue'])
# <ipython-input-11-57e7edc93347>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=scaled_frame2, x="Channel", y="Milk", estimator=sum, ci=None, palette=['red', 'blue'])

# %% [markdown]
# Total de lo que se gastó de leche por región.

# %%
leche_por_region = df.groupby("Region")["Milk"].sum()
leche_por_region
# Out:
# Region
# 1     422454
# 2     239144
# 3    1888759
# Name: Milk, dtype: int64

# %% [markdown]
# Total de lo que se gastó de abarrotes por canal.

# %%
abarrotes_por_canal = df.groupby("Channel")["Grocery"].sum()
abarrotes_por_canal
# Out:
# Channel
# 1    1180717
# 2    2317845
# Name: Grocery, dtype: int64

# %% [markdown]
# ONE HOT ENCODING

# %%
from sklearn.preprocessing import OneHotEncoder
data = {
    "Nombre": ["Ana", "Luis", "Sofia", "Pedro", "Elana"],
    "Ciudad": ["Monterrey", "Guadalajara", "CDMX", "Monterrey", "Guadalajara"],
    "Edad": [25, 30, 28, 35, 27]
}

df = pd.DataFrame(data)

print(f"Original Data:\n{df}\n")
df_pandas_encoded = pd.get_dummies(df, columns=["Ciudad"], drop_first=True)
print(f"One-Hot Encoded Data using Pandas:\n{df_pandas_encoded}\n")

encoder = OneHotEncoder(sparse_output=False)
one_hot_encoded = encoder.fit_transform(df[["Ciudad"]])
one_hot_df = pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(["Ciudad"]))
df_sklearn_encoded = pd.concat([df.drop(["Ciudad"], axis=1), one_hot_df], axis=1)
print(f"One-Hot Encoded Data using Scikit-Learn:\n{df_sklearn_encoded}\n")
# Out:
# Original Data:
#   Nombre       Ciudad  Edad
# 0    Ana    Monterrey    25
# 1   Luis  Guadalajara    30
# 2  Sofia         CDMX    28
# 3  Pedro    Monterrey    35
# 4  Elana  Guadalajara    27
#
# One-Hot Encoded Data using Pandas:
#   Nombre  Edad  Ciudad_Guadalajara  Ciudad_Monterrey
# 0    Ana    25               False              True
# 1   Luis    30                True             False
# 2  Sofia    28               False             False
# 3  Pedro    35               False              True
# 4  Elana    27                True             False
#
# One-Hot Encoded Data using Scikit-Learn:
#   Nombre  Edad  Ciudad_CDMX  Ciudad_Guadalajara  Ciudad_Monterrey
# 0    Ana    25          0.0                 0.0               1.0
# 1   Luis    30          0.0                 1.0               0.0
# 2  Sofia    28          1.0                 0.0               0.0
# 3  Pedro    35          0.0                 0.0               1.0
# 4  Elana    27          0.0                 1.0               0.0

# %% [markdown]
# ## Mapa Conceptual Aprendizaje Automático

# %% [markdown]
# ![Mapa conceptual.png](data:image/png;base64,...)
